# %% [markdown]
# #Analyse exploratoire des données Netflix : Exécution du Projet
# Commençons par analyser les données Netflix fournies. Nous allons d'abord explorer les données pour comprendre leur structure et le type d'informations qu'elles contiennent. Une fois cette étape terminée, nous pourrons extraire des insights utiles pour l'étude de la concurrence.
#
# Commençons par la première étape : lire et examiner les données.
#
# 🖥 Lecture des données

# %%
import pandas as pd
# Lecture du fichier csv
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-36e10b10-7a65-48ec-97ab-b6d4157e0f6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36e10b10-7a65-48ec-97ab-b6d4157e0f6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
# Affichage des premières lignes pour examiner la structure des données
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Étapes suivantes :
#
# 1. Nettoyage des données : Traiter les valeurs manquantes et vérifier la cohérence des données.
# 2. Analyse exploratoire :
# - Distribution des types de contenu (films vs séries)
# - Analyse des genres et catégories
# - Analyse par pays d'origine
# - Analyse des durées et des saisons
# - Distribution des dates d'ajout et des années de sortie
# 3. Visualisation des données : Créer des graphiques pour illustrer les principales observations.
# 4. Préparation des livrables : Notebook et présentation PowerPoint.
# Commençons par une étape de nettoyage des données et une analyse exploratoire.
#
# 🖥 Nettoyage des données et analyse exploratoire

# %%
# Information sur le dataset pour vérifier les valeurs manquantes et les types de données
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Les données montrent des valeurs manquantes dans plusieurs colonnes. Voici un résumé des colonnes avec des valeurs manquantes et des insights principaux :
#
# - director: 2634 valeurs manquantes
# - cast: 825 valeurs manquantes
# - country: 831 valeurs manquantes
# - date_added: 10 valeurs manquantes
# - rating: 4 valeurs manquantes
# - duration: 3 valeurs manquantes

# %%
# Statistiques descriptives des données
df.describe(include='all').T
# Out:
#                count unique  \
# show_id         8807   8807
# type            8807      2
# title           8807   8807
# director        6173   4528
# cast            7982   7692
# country         7976    748
# date_added      8797   1767
# release_year  8807.0    NaN
# rating          8803     17
# duration        8804    220
# listed_in       8807    514
# description     8807   8775
#
#                                                             top  freq  \
# show_id                                                      s1     1
# type                                                      Movie  6131
# title                                      Dick Johnson Is Dead     1
# director                                          Rajiv Chilaka    19
# cast                                         David Attenborough    19
# country                                           United States  2818
# date_added                                      January 1, 2020   109
# ...

# %% [markdown]
# Étapes de nettoyage
#
# 1. Traiter les valeurs manquantes : Pour les colonnes critiques, nous pourrions imputer des valeurs ou les remplacer par des indicateurs spécifiques.
# 2. Vérifier et convertir les types de données : La colonne date_added doit être convertie en type date.
#
# Exploration initiale
#
# 1. Distribution des types de contenu (films vs séries).
# 2. Analyse des genres et catégories.
# 3. Analyse par pays d'origine.
# 4. Analyse des durées et des saisons.
# 5. Distribution des dates d'ajout et des années de sortie.
#
# 🖥 Nettoyage des données

# %%
# Remplacer les valeurs manquantes par des indicateurs spécifiques
df['director'].fillna('Unknown', inplace=True)
df['cast'].fillna('Unknown', inplace=True)
df['country'].fillna('Unknown', inplace=True)
df['date_added'].fillna('Unknown', inplace=True)
df['rating'].fillna('Unknown', inplace=True)
df['duration'].fillna('Unknown', inplace=True)

# Convertir date_added en type date
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# Réexamen des données après nettoyage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8709 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB
# <ipython-input-7-ebd6cf2ec7f2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# Les données ont été nettoyées avec succès. Voici le plan pour l'analyse exploratoire des données :
#
# Analyse exploratoire
#
# 1. Distribution des types de contenu :
#   - Répartition entre films et séries.
#
# 2. Analyse des genres et catégories :
#   - Fréquence des différents genres.
#
# 3. Analyse par pays d'origine :
#   - Nombre de titres par pays.
#
# 4. Analyse des durées et des saisons :
#   - Distribution des durées des films.
#   - Distribution du nombre de saisons pour les séries.
#
# 5. Distribution des dates d'ajout et des années de sortie :
#   - Distribution des dates d'ajout.
#   - Distribution des années de sortie.
#
# 🖥 Distribution des types de contenu

# %%
import matplotlib.pyplot as plt

# Distribution des types de contenu
content_type_counts = df['type'].value_counts()

# Visualisation
plt.figure(figsize=(8, 6))
content_type_counts.plot(kind='bar', color=['skyblue', 'lightgreen'])
plt.title('Distribution des Types de Contenu')
plt.xlabel('Type de Contenu')
plt.ylabel('Nombre de Titres')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 🖥 Analyse des genres et catégories

# %%
# Compter les genres
genre_counts = df['listed_in'].str.split(', ').explode().value_counts().head(10)

# Visualisation
plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar', color='lightcoral')
plt.title('Top 10 Genres de Contenu')
plt.xlabel('Genre')
plt.ylabel('Nombre de Titres')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# 🖥 Analyse par pays d'origine

# %%
# Compter les pays
country_counts = df['country'].str.split(', ').explode().value_counts().head(10)

# Visualisation
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='lightseagreen')
plt.title('Top 10 Pays d\'Origine des Titres')
plt.xlabel('Pays')
plt.ylabel('Nombre de Titres')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# 🖥 Analyse des durées et des saisons

# %%
# Séparer les films et les séries
movies = df[df['type'] == 'Movie']
tv_shows = df[df['type'] == 'TV Show']

# %%
print(movies.shape)
movies.head()
# Out:
# (6131, 12)
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                             Unknown
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country date_added  \
# ...

# %%
# Filtrer les valeurs "Unknown" avant de convertir la colonne duration en entier
movies = movies[movies['duration'] != 'Unknown']

# Distribution des durées des films
movies['duration'] = movies['duration'].str.replace(' min', '').astype(int)

plt.figure(figsize=(10, 6))
movies['duration'].plot(kind='hist', bins=30, color='lightskyblue')
plt.title('Distribution des Durées des Films')
plt.xlabel('Durée (minutes)')
plt.ylabel('Nombre de Films')
plt.show()
# Out:
# <ipython-input-13-d2529a1208d2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration'] = movies['duration'].str.replace(' min', '').astype(int)

# %%
tv_shows = tv_shows[tv_shows['duration'] != 'Unknown']

# Distribution des saisons des séries
tv_shows['duration'] = tv_shows['duration'].str.replace(' Season', '').str.replace('s', '').astype(int)

plt.figure(figsize=(10, 6))
tv_shows['duration'].plot(kind='hist', bins=10, color='lightcoral')
plt.title('Distribution du Nombre de Saisons des Séries')
plt.xlabel('Nombre de Saisons')
plt.ylabel('Nombre de Séries')
plt.show()

# %% [markdown]
# 🖥 Distribution des dates d'ajout et des années de sortie

# %%
# Distribution des dates d'ajout
plt.figure(figsize=(10, 6))
df['date_added'].dt.year.value_counts().sort_index().plot(kind='bar', color='mediumseagreen')
plt.title('Distribution des Dates d\'Ajout')
plt.xlabel('Année')
plt.ylabel('Nombre de Titres Ajoutés')
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution des années de sortie
plt.figure(figsize=(18, 6))
df['release_year'].value_counts().sort_index().plot(kind='bar', color='mediumpurple')
plt.title('Distribution des Années de Sortie')
plt.xlabel('Année')
plt.ylabel('Nombre de Titres Sortis')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Les analyses exploratoires sont terminées et les visualisations fournissent des insights intéressants sur les données Netflix. Voici un résumé des résultats principaux :
#
# 1. Distribution des types de contenu :
#   - La majorité des titres sont des films.
#
# 2. Top 10 genres de contenu :
#   - Les genres les plus fréquents incluent les Dramas, les Documentaires et les Séries TV internationales.
#
# 3. Top 10 pays d'origine des titres :
#   - Les États-Unis dominent en termes de nombre de titres, suivis par l'Inde et le Royaume-Uni.
#
# 4. Distribution des durées des films :
#   - La plupart des films durent entre 80 et 100 minutes.
#
# 5. Distribution du nombre de saisons des séries :
#   - La majorité des séries ont une ou deux saisons.
#
# 6. Distribution des dates d'ajout :
#   - Une augmentation notable des titres ajoutés au fil des années, avec un pic récent.
#
# 7. Distribution des années de sortie :
#   - La majorité des titres sont des productions récentes, principalement après 2000.
#
# Étapes suivantes
#
# Création du Notebook : Compiler tous les codes, résultats et explications dans un colab notebook.
